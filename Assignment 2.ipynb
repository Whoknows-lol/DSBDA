# %%
import numpy as np 
import pandas as pd
df=pd.read_csv("AcadmicData.csv")
df
# Out:
#      gender race/ethnicity parental level of education  ... math score reading score writing score
# 0    female        group B           bachelor's degree  ...         72          72.0          74.0
# 1    female        group C                some college  ...         69          90.0          88.0
# 2    female        group B             master's degree  ...        NaN          95.0          93.0
# 3      male        group A          associate's degree  ...         47          57.0          44.0
# 4      male        group C                some college  ...         76          78.0          75.0
# ..      ...            ...                         ...  ...        ...           ...           ...
# 995  female        group E             master's degree  ...         88          99.0          95.0
# 996    male        group C                 high school  ...         62          55.0          55.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   987 non-null    object
#  6   reading score                978 non-null    float64
#  7   writing score                988 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education  ... math score reading score writing score
# 0  female        group B           bachelor's degree  ...         72          72.0          74.0
# 1  female        group C                some college  ...         69          90.0          88.0
# 2  female        group B             master's degree  ...        NaN          95.0          93.0
# 3    male        group A          associate's degree  ...         47          57.0          44.0
# 4    male        group C                some college  ...         76          78.0          75.0
#
# [5 rows x 8 columns]

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education  ... math score reading score writing score
# 0  female        group B           bachelor's degree  ...         72          72.0          74.0
# 1  female        group C                some college  ...         69          90.0          88.0
# 2  female        group B             master's degree  ...        NaN          95.0          93.0
# 3    male        group A          associate's degree  ...         47          57.0          44.0
# 4    male        group C                some college  ...         76          78.0          75.0
# 5  female        group B          associate's degree  ...         71           NaN          78.0
# 6  female        group B                some college  ...         88          95.0          92.0
# 7    male        group B                some college  ...         40          43.0          39.0
# 8    male        group D                 high school  ...         64          64.0           NaN
# ...

# %%
df.describe()
# Out:
#        reading score  writing score
# count     978.000000     988.000000
# mean       69.306748      68.180162
# std        14.579608      15.171626
# min        17.000000      10.000000
# 25%        59.000000      58.000000
# 50%        70.000000      69.000000
# 75%        79.750000      79.000000
# max       100.000000     100.000000

# %%
df.isna().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     13
# reading score                  22
# writing score                  12
# dtype: int64

# %%
import seaborn as sns
sns.boxenplot(df)
# Out:
# <Axes: >

# %%
sns.boxenplot(df)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['reading score'],y=df['writing score'],color='red')
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
sns.scatterplot(x=df['math score'],y=df['writing score'],color='red')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>
